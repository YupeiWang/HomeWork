# %%
# !wget "https://raw.githubusercontent.com/AllenDowney/ThinkDSP/master/code/thinkdsp.py"
# !wget "https://raw.githubusercontent.com/AllenDowney/ThinkDSP/master/code/thinkplot.py"
# !wget "https://raw.githubusercontent.com/AllenDowney/ThinkDSP/master/code/thinkstats2.py"
# Out:
# --2020-05-05 06:29:21--  https://raw.githubusercontent.com/AllenDowney/ThinkDSP/master/code/thinkdsp.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48075 (47K) [text/plain]
# Saving to: ‘thinkdsp.py.2’
#
# thinkdsp.py.2       100%[===================>]  46.95K  --.-KB/s    in 0.01s
#
# 2020-05-05 06:29:22 (3.25 MB/s) - ‘thinkdsp.py.2’ saved [48075/48075]
#
# --2020-05-05 06:29:23--  https://raw.githubusercontent.com/AllenDowney/ThinkDSP/master/code/thinkplot.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
from __future__ import print_function, division

import thinkdsp
import thinkplot
import thinkstats2

import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

# %matplotlib inline

# %% [markdown]
# 第一題

# %%
signal=thinkdsp.UncorrelatedUniformNoise()
x=signal.make_wave(duration=1,framerate=10000)

x.ys.shape
# Out:
# (10000,)

# %% [markdown]
# 第二題

# %%
x.plot()

# %%
x.ys.max()
# Out:
# 0.9999239581397092

# %%
x.ys.mean(), x.ys.std()
# Out:
# (-0.002148693320898528, 0.5784303796281607)

# %% [markdown]
# 第三題

# %%
sx=x.make_spectrum().plot()

# %%
sx.hs.shape
# Out:
# (5001,)

# %% [markdown]
# 第四題

# %%
import thinkdsp as td
x= td.UncorrelatedUniformNoise()
w= x.make_wave()
spec= w.make_spectrum()
specInt= spec.make_integrated_spectrum()

# %%
spec.plot()

# %% [markdown]
# 第五題

# %%
import thinkdsp as td
x= td.UncorrelatedUniformNoise()
w= x.make_wave()
spec= w.make_spectrum()
specInt= spec.make_integrated_spectrum()
spec.plot()
plt.xscale('log')
plt.yscale('log')

# %% [markdown]
# 第六題

# %%
import numpy as  np
import scipy as sp

x= np.random.random(100)
y= np.random.random(100) + x
pl.scatter(x,y);pl.grid(True)
sp.stats.linregress(x,y)
# Out:
# LinregressResult(slope=1.1687845123432488, intercept=0.4587667919980889, rvalue=0.7379789042094366, pvalue=1.9691206534743006e-18, stderr=0.1079612346530546)
