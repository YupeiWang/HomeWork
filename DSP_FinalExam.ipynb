# %%
from __future__ import print_function, division

import thinkdsp
import thinkplot

import numpy as np

import warnings
warnings.filterwarnings('ignore')

PI2 = 2 * np.pi

np.set_printoptions(precision=3, suppress=True)
# %matplotlib inline

# %% [markdown]
# # 【1】

# %% [markdown]
# ### (a)

# %%
x1=[1,0,0,0,0,0,0,0]
xf1=np.fft.fft(x1)
xf1
# Out:
# array([1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j])

# %% [markdown]
# ### (b)

# %%
x2=[1,1,1,1,1,1,1,1]
xf2=np.fft.fft(x2)
xf2
# Out:
# array([8.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j])

# %% [markdown]
# ### (c)

# %%
x3=[1,-1,1,-1,1,-1,1,-1]
xf3=np.fft.fft(x3)
xf3
# Out:
# array([0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 8.+0.j, 0.+0.j, 0.+0.j, 0.+0.j])

# %% [markdown]
# ### (d)

# %%
x4=[3,0,2,0,2,0,2,0]
xf4=np.fft.fft(x4)
xf4
# Out:
# array([9.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 9.+0.j, 1.+0.j, 1.+0.j, 1.+0.j])

# %% [markdown]
# ### (e)

# %%
x5=[1,1,0,0,0,0,1,1]
x6=[1,1,0,0,0,0,0,1]
idf5=np.fft.ifft(x5)
idf6=np.fft.ifft(x6)
idf5
# Out:
# array([ 0.5  +0.j   ,  0.302-0.125j,  0.   +0.j   , -0.052+0.125j,
#         0.   +0.j   , -0.052-0.125j,  0.   +0.j   ,  0.302+0.125j])

# %% [markdown]
# ### (f)
#
# Ans：x5[n]

# %% [markdown]
# ### (g)

# %%
x7=[1,1,0,0]
x8=[1,1,0,0,0,0,0,0]
xf7=np.fft.fft(x7)
xf8=np.fft.fft(x8)
xf8
# Out:
# array([2.   +0.j   , 1.707-0.707j, 1.   -1.j   , 0.293-0.707j,
#        0.   +0.j   , 0.293+0.707j, 1.   +1.j   , 1.707+0.707j])

# %% [markdown]
# # 【2】

# %% [markdown]
# ### (b)

# %%
np.convolve([1, 1, 1, 1], [1, 1])
# Out:
# array([1, 2, 2, 2, 1])

# %% [markdown]
# ### (d)

# %%
x=[1,1,1,1]
w=[1,1]
y=[1,2,2,2,1]
np.fft.fft(y)
# Out:
# array([ 8.   +0.j   , -1.309-0.951j, -0.191-0.588j, -0.191+0.588j,
#        -1.309+0.951j])

# %% [markdown]
# # 【3】

# %% [markdown]
# ### (a)

# %% [markdown]
# 在合適的條件下，傅立葉變換一個的卷積兩個信號是逐點乘積的傅立葉變換。
# 換句話說，一個域（例如，時域）中的捲積等於另一域（例如，頻域）中的逐點乘法。
# 卷積定理的版本適用於各種與傅立葉相關的變換。讓f和g是帶捲積的兩個函數f*g。(在這種情況下，星號表示卷積)

# %% [markdown]
# ### (b)

# %%
from IPython.display import Image
from IPython.core.display import HTML 
PATH = "111511.jpg" 
Image(filename = PATH , width=1896, height=2592)
